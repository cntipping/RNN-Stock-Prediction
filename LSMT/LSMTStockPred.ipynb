# %% [markdown]
# # Stock Prediction LSMT

# %% [markdown]
# ## Import Libraries + Download Data + Fetch Stock Data

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import psutil
import os
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard

# %%
cpu_usage_log = []
memory_usage_log = []

# %%
ticker = "AAPL"
data = yf.download(ticker, start="2010-01-01", end="2023-11-13")
df = data[['Close']].reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## CPU + RAM Monitoring

# %%
def log_hardware_usage():
    process = psutil.Process(os.getpid())
    cpu_percent = psutil.cpu_percent(interval=1)
    memory_info = process.memory_info()
    
    cpu_usage_log.append(cpu_percent)
    memory_usage_log.append(memory_info.rss / 1024 ** 2)  # in MB

from tensorflow.keras.callbacks import Callback

class HardwareLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        log_hardware_usage()

# %% [markdown]
# ## Preprocess Data

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df['Close'].values.reshape(-1, 1))

# %% [markdown]
# ## Create Sequences

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), 0])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

seq_length = 60
X, y = create_sequences(scaled_data, seq_length)

# %% [markdown]
# ## Split and Reshape data

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ## Build LSTM Model

# %%
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(seq_length, 1)),
    LSTM(50, return_sequences=False),
    Dense(25),
    Dense(1)
])
# Out:
# /opt/anaconda3/envs/stock_pred/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Train Model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)
hardware_logger = HardwareLogger()
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_split=0.1, verbose=1, callbacks=[tensorboard_callback, hardware_logger])
# Out:
# Epoch 1/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 4.2596e-05 - val_loss: 1.9197e-04
# Epoch 2/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.0311e-06 - val_loss: 3.1427e-04
# Epoch 3/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.5562e-06 - val_loss: 2.6703e-04
# Epoch 4/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.5292e-05 - val_loss: 2.1809e-04
# Epoch 5/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.2337e-06 - val_loss: 2.0371e-04
# Epoch 6/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 7.5437e-06 - val_loss: 1.9734e-04
# Epoch 7/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 6.9814e-06 - val_loss: 1.9482e-04
# Epoch 8/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.6684e-06 - val_loss: 2.8863e-04
# Epoch 9/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.7157e-06 - val_loss: 2.0054e-04
# Epoch 10/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.7745e-06 - val_loss: 2.1910e-04
# Epoch 11/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.4247e-06 - val_loss: 2.5835e-04
# Epoch 12/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.3505e-06 - val_loss: 2.0385e-04
# Epoch 13/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0350e-05 - val_loss: 2.2071e-04
# Epoch 14/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.2538e-06 - val_loss: 2.7805e-04
# Epoch 15/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0399e-05 - val_loss: 1.9782e-04
# Epoch 16/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.7295e-06 - val_loss: 1.9502e-04
# Epoch 17/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.3765e-06 - val_loss: 5.7910e-04
# Epoch 18/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 3.0663e-05 - val_loss: 1.9358e-04
# Epoch 19/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.0359e-06 - val_loss: 2.0233e-04
# Epoch 20/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.1415e-05 - val_loss: 2.2395e-04
# Epoch 21/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 7.2631e-06 - val_loss: 2.0372e-04
# Epoch 22/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.7434e-06 - val_loss: 2.4481e-04
# Epoch 23/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.2040e-06 - val_loss: 1.9463e-04
# Epoch 24/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.2314e-06 - val_loss: 1.9347e-04
# Epoch 25/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.8660e-06 - val_loss: 2.3931e-04
# Epoch 26/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.8807e-06 - val_loss: 2.0285e-04
# Epoch 27/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.4519e-06 - val_loss: 2.0195e-04
# Epoch 28/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.4708e-06 - val_loss: 2.5730e-04
# Epoch 29/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.6766e-06 - val_loss: 1.9477e-04
# Epoch 30/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.6156e-06 - val_loss: 1.9313e-04
# Epoch 31/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.8898e-06 - val_loss: 2.2817e-04
# Epoch 32/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.0842e-06 - val_loss: 2.3368e-04
# Epoch 33/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.7905e-06 - val_loss: 2.5177e-04
# Epoch 34/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.6950e-06 - val_loss: 2.0155e-04
# Epoch 35/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.5434e-06 - val_loss: 1.9408e-04
# Epoch 36/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.3960e-06 - val_loss: 1.9901e-04
# Epoch 37/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.2761e-06 - val_loss: 2.2487e-04
# Epoch 38/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.9821e-06 - val_loss: 2.2696e-04
# Epoch 39/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.3539e-06 - val_loss: 3.1073e-04
# Epoch 40/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.6451e-06 - val_loss: 2.5390e-04
# Epoch 41/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.8524e-06 - val_loss: 1.9686e-04
# Epoch 42/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.3661e-06 - val_loss: 1.9737e-04
# Epoch 43/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.8614e-06 - val_loss: 1.9685e-04
# Epoch 44/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.1008e-05 - val_loss: 1.9673e-04
# Epoch 45/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.6824e-06 - val_loss: 2.7796e-04
# Epoch 46/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.8159e-06 - val_loss: 2.0976e-04
# Epoch 47/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.2547e-06 - val_loss: 1.9338e-04
# Epoch 48/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.2186e-06 - val_loss: 2.6624e-04
# Epoch 49/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0284e-05 - val_loss: 1.9317e-04
# Epoch 50/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.3680e-06 - val_loss: 2.1891e-04
# Epoch 51/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.0416e-06 - val_loss: 1.9799e-04
# Epoch 52/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.5558e-06 - val_loss: 1.9389e-04
# Epoch 53/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.3576e-06 - val_loss: 1.9220e-04
# Epoch 54/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.7061e-06 - val_loss: 2.0645e-04
# Epoch 55/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.0870e-06 - val_loss: 2.0300e-04
# Epoch 56/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.0615e-06 - val_loss: 2.0687e-04
# Epoch 57/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.4002e-06 - val_loss: 1.9542e-04
# Epoch 58/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.5105e-06 - val_loss: 2.0437e-04
# Epoch 59/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.3706e-06 - val_loss: 2.1478e-04
# Epoch 60/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.9617e-06 - val_loss: 1.9328e-04
# Epoch 61/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.0109e-06 - val_loss: 1.9351e-04
# Epoch 62/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.3697e-06 - val_loss: 1.9488e-04
# Epoch 63/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.7674e-06 - val_loss: 1.9589e-04
# Epoch 64/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.7275e-06 - val_loss: 1.9177e-04
# Epoch 65/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.2934e-06 - val_loss: 1.9699e-04
# Epoch 66/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.4874e-06 - val_loss: 2.3278e-04
# Epoch 67/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.7016e-06 - val_loss: 1.9329e-04
# Epoch 68/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.3551e-06 - val_loss: 2.2783e-04
# Epoch 69/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 9.8368e-06 - val_loss: 2.4530e-04
# Epoch 70/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 7.7857e-06 - val_loss: 1.9543e-04
# Epoch 71/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.6821e-06 - val_loss: 2.1371e-04
# Epoch 72/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.6117e-06 - val_loss: 1.9494e-04
# Epoch 73/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.2120e-06 - val_loss: 2.1599e-04
# Epoch 74/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.9086e-06 - val_loss: 2.0534e-04
# Epoch 75/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.2125e-06 - val_loss: 1.9431e-04
# Epoch 76/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.3169e-06 - val_loss: 2.1995e-04
# Epoch 77/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.8893e-06 - val_loss: 2.0226e-04
# Epoch 78/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.2428e-06 - val_loss: 2.0420e-04
# Epoch 79/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.9190e-06 - val_loss: 1.9778e-04
# Epoch 80/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.7851e-06 - val_loss: 2.4204e-04
# Epoch 81/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.7557e-06 - val_loss: 1.9752e-04
# Epoch 82/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.7444e-06 - val_loss: 2.3707e-04
# Epoch 83/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 8.6394e-06 - val_loss: 2.2465e-04
# Epoch 84/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 8.2371e-06 - val_loss: 2.2550e-04
# Epoch 85/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.6579e-06 - val_loss: 2.0117e-04
# Epoch 86/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.2817e-06 - val_loss: 2.1776e-04
# Epoch 87/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0960e-05 - val_loss: 2.3401e-04
# Epoch 88/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.6773e-06 - val_loss: 1.9427e-04
# Epoch 89/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.2861e-06 - val_loss: 1.9189e-04
# Epoch 90/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.4653e-06 - val_loss: 2.7537e-04
# Epoch 91/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.2618e-06 - val_loss: 2.0309e-04
# Epoch 92/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.6063e-06 - val_loss: 1.9232e-04
# Epoch 93/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.4320e-06 - val_loss: 2.2385e-04
# Epoch 94/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.6262e-06 - val_loss: 2.0610e-04
# Epoch 95/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.2981e-06 - val_loss: 1.9194e-04
# Epoch 96/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.2624e-06 - val_loss: 2.0483e-04
# Epoch 97/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.6476e-06 - val_loss: 1.9382e-04
# Epoch 98/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.4120e-06 - val_loss: 2.0382e-04
# Epoch 99/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 6.6404e-06 - val_loss: 1.9664e-04
# Epoch 100/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 7.6570e-06 - val_loss: 2.1122e-04

# %% [markdown]
# ## Make Predicitions + RMSE

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

rmse = np.sqrt(np.mean((predictions - y_test)**2))
print(f"RMSE: {rmse}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# RMSE: 29035.577187077368

# %% [markdown]
# ## Plot Predictions + Hardware Usage

# %%
import matplotlib.pyplot as plt

# Plot the results
plt.figure(figsize=(14,5))
plt.plot(y_test, label='Actual')
plt.plot(predictions, label='Predicted')
plt.title("Actual vs Predicted Stock Prices")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %%
epochs = range(len(cpu_usage_log))

plt.figure(figsize=(14,6))

plt.subplot(2,1,1)
plt.plot(epochs, cpu_usage_log, label='CPU Usage (%)')
plt.xlabel("Epoch")
plt.ylabel("CPU %")
plt.legend()

plt.subplot(2,1,2)
plt.plot(epochs, memory_usage_log, label='Memory Usage (MB)')
plt.xlabel("Epoch")
plt.ylabel("Memory (MB)")
plt.legend()

plt.tight_layout()
plt.show()
