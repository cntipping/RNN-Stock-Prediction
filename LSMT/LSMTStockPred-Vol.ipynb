# %% [markdown]
# # Stock Prediction LSMT

# %% [markdown]
# ## Import Libraries + Download Data + Fetch Stock Data

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import psutil
import os
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard

# %%
cpu_usage_log = []
memory_usage_log = []

# %%
ticker = "AAPL"
data = yf.download(ticker, start="2010-01-01", end="2023-11-13")
df = data[['Close', 'Volume']].reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## CPU + RAM Monitoring

# %%
def log_hardware_usage():
    process = psutil.Process(os.getpid())
    cpu_percent = psutil.cpu_percent(interval=1)
    memory_info = process.memory_info()
    
    cpu_usage_log.append(cpu_percent)
    memory_usage_log.append(memory_info.rss / 1024 ** 2)  # in MB

from tensorflow.keras.callbacks import Callback

class HardwareLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        log_hardware_usage()

# %% [markdown]
# ## Preprocess Data

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['Close', 'Volume']])

# %% [markdown]
# ## Create Sequences

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

seq_length = 60
X, y = create_sequences(scaled_data, seq_length)

# %% [markdown]
# ## Split and Reshape data

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# ## Build LSTM Model

# %%
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(seq_length, 2)),
    LSTM(50, return_sequences=False),
    Dense(25),
    Dense(1)
])
# Out:
# /opt/anaconda3/envs/stock_pred/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Train Model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)
hardware_logger = HardwareLogger()
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_split=0.1, verbose=1, callbacks=[tensorboard_callback, hardware_logger])
# Out:
# Epoch 1/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 2/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 4.7315e-05 - val_loss: 0.0012
# Epoch 3/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 3.6845e-05 - val_loss: 0.0010
# Epoch 4/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 4.3506e-05 - val_loss: 9.6864e-04
# Epoch 5/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.3688e-05 - val_loss: 0.0011
# Epoch 6/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.8286e-05 - val_loss: 9.5566e-04
# Epoch 7/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 3.8977e-05 - val_loss: 7.9640e-04
# Epoch 8/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.0516e-05 - val_loss: 7.3135e-04
# Epoch 9/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.1568e-05 - val_loss: 9.5482e-04
# Epoch 10/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.6658e-05 - val_loss: 0.0010
# Epoch 11/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 3.8762e-05 - val_loss: 8.0967e-04
# Epoch 12/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.2724e-05 - val_loss: 7.9167e-04
# Epoch 13/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 3.2035e-05 - val_loss: 6.3841e-04
# Epoch 14/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.1388e-05 - val_loss: 5.3139e-04
# Epoch 15/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.9107e-05 - val_loss: 5.5023e-04
# Epoch 16/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.4055e-05 - val_loss: 7.4071e-04
# Epoch 17/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 2.3324e-05 - val_loss: 5.3133e-04
# Epoch 18/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.8791e-05 - val_loss: 5.0722e-04
# Epoch 19/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 3.2429e-05 - val_loss: 5.2906e-04
# Epoch 20/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.9326e-05 - val_loss: 0.0028
# Epoch 21/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.5866e-05 - val_loss: 6.9889e-04
# Epoch 22/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.6085e-05 - val_loss: 5.0408e-04
# Epoch 23/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.9887e-05 - val_loss: 6.7519e-04
# Epoch 24/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.1581e-05 - val_loss: 5.9763e-04
# Epoch 25/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss:
100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0186e-05 - val_loss: 3.2034e-04
# Epoch 74/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.2526e-05 - val_loss: 3.1582e-04
# Epoch 75/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 7.4121e-06 - val_loss: 3.5799e-04
# Epoch 76/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.4984e-06 - val_loss: 2.6204e-04
# Epoch 77/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0575e-05 - val_loss: 1.9742e-04
# Epoch 78/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.9314e-06 - val_loss: 2.2260e-04
# Epoch 79/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.4267e-05 - val_loss: 2.6014e-04
# Epoch 80/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.0907e-06 - val_loss: 3.2707e-04
# Epoch 81/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.0066e-06 - val_loss: 4.6841e-04
# Epoch 82/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0926e-05 - val_loss: 3.5385e-04
# Epoch 83/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0946e-05 - val_loss: 2.8502e-04
# Epoch 84/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.3070e-06 - val_loss: 2.5880e-04
# Epoch 85/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.1889e-06 - val_loss: 3.4948e-04
# Epoch 86/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.0474e-05 - val_loss: 3.0825e-04
# Epoch 87/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.7914e-06 - val_loss: 2.3225e-04
# Epoch 88/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 7.6316e-06 - val_loss: 6.6653e-04
# Epoch 89/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.6174e-05 - val_loss: 2.0127e-04
# Epoch 90/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.5042e-05 - val_loss: 2.3578e-04
# Epoch 91/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.3329e-06 - val_loss: 2.8978e-04
# Epoch 92/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.8116e-06 - val_loss: 7.6101e-04
# Epoch 93/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0430e-05 - val_loss: 3.3370e-04
# Epoch 94/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.8551e-06 - val_loss: 1.9373e-04
# Epoch 95/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.4291e-06 - val_loss: 1.9503e-04
# Epoch 96/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.3217e-06 - val_loss: 2.1344e-04
# Epoch 97/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 9.5563e-06 - val_loss: 2.1647e-04
# Epoch 98/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0997e-05 - val_loss: 2.3568e-04
# Epoch 99/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.5488e-06 - val_loss: 2.8459e-04
# Epoch 100/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 6.3973e-06 - val_loss: 2.2291e-04

# %% [markdown]
# ## Make Predicitions + RMSE

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(np.concatenate((predictions, np.zeros_like(predictions)), axis=1))[:, 0]
y_test = scaler.inverse_transform(np.concatenate((y_test.reshape(-1, 1), np.zeros_like(y_test.reshape(-1, 1))), axis=1))[:, 0]

rmse = np.sqrt(np.mean((predictions - y_test)**2))
print(f"RMSE (with Volume): {rmse}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RMSE (with Volume): 3.6001607764039716

# %% [markdown]
# ## Plot Predictions + Hardware Usage

# %%
import matplotlib.pyplot as plt

# Plot the results
plt.figure(figsize=(14,5))
plt.plot(y_test, label='Actual')
plt.plot(predictions, label='Predicted')
plt.title("Actual vs Predicted Stock Prices")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %%
epochs = range(len(cpu_usage_log))

plt.figure(figsize=(14,6))

plt.subplot(2,1,1)
plt.plot(epochs, cpu_usage_log, label='CPU Usage (%)')
plt.xlabel("Epoch")
plt.ylabel("CPU %")
plt.legend()

plt.subplot(2,1,2)
plt.plot(epochs, memory_usage_log, label='Memory Usage (MB)')
plt.xlabel("Epoch")
plt.ylabel("Memory (MB)")
plt.legend()

plt.tight_layout()
plt.show()
