# %% [markdown]
# # Stock Predicition GRU (Base)

# %% [markdown]
# ## Import Libraries + Download Data + Fetch Stock Data

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import psutil
import os
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.callbacks import TensorBoard
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
cpu_usage_log = []
memory_usage_log = []

# %%
ticker = "AAPL"
data = yf.download(ticker, start="2010-01-01", end="2023-11-13")
df = data[['Open', 'High', 'Low', 'Close', 'Volume']].reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## CPU + RAM Monitoring

# %%
def log_hardware_usage():
    process = psutil.Process(os.getpid())
    cpu_percent = psutil.cpu_percent(interval=1)
    memory_info = process.memory_info()
    
    cpu_usage_log.append(cpu_percent)
    memory_usage_log.append(memory_info.rss / 1024 ** 2)  # in MB

from tensorflow.keras.callbacks import Callback

class HardwareLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        log_hardware_usage()

# %% [markdown]
# ## Prep Data

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['Open', 'High', 'Low', 'Close', 'Volume']])

# %% [markdown]
# ## Create Sequences

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 3])  # Close is index 3
    return np.array(X), np.array(y)

seq_length = 60
X, y = create_sequences(scaled_data, seq_length)

# %% [markdown]
# ## Split Data

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# ## Build GRU Model

# %%
model = Sequential([
    GRU(50, return_sequences=True, input_shape=(seq_length, 5)),
    GRU(50, return_sequences=False),
    Dense(25),
    Dense(1)
])
# Out:
# /opt/anaconda3/envs/stock_pred/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Train Model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)
hardware_logger = HardwareLogger()
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_split=0.1, verbose=1, callbacks=[tensorboard_callback, hardware_logger])
# Out:
# Epoch 1/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0022 - val_loss: 6.6309e-04
# Epoch 2/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.8711e-05 - val_loss: 4.4338e-04
# Epoch 3/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.8529e-05 - val_loss: 4.5822e-04
# Epoch 4/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.5238e-05 - val_loss: 3.4081e-04
# Epoch 5/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.4435e-05 - val_loss: 3.5013e-04
# Epoch 6/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.1885e-05 - val_loss: 3.1039e-04
# Epoch 7/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.1944e-05 - val_loss: 3.4886e-04
# Epoch 8/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.6661e-05 - val_loss: 2.8635e-04
# Epoch 9/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.2764e-05 - val_loss: 3.0517e-04
# Epoch 10/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.1837e-05 - val_loss: 3.4077e-04
# Epoch 11/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.3319e-05 - val_loss: 2.7515e-04
# Epoch 12/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2988e-05 - val_loss: 3.2997e-04
# Epoch 13/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.3725e-05 - val_loss: 2.4465e-04
# Epoch 14/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.4388e-05 - val_loss: 2.6479e-04
# Epoch 15/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2779e-05 - val_loss: 3.2527e-04
# Epoch 16/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2137e-05 - val_loss: 2.5031e-04
# Epoch 17/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2562e-05 - val_loss: 2.2780e-04
# Epoch 18/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0967e-05 - val_loss: 2.5576e-04
# Epoch 19/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2742e-05 - val_loss: 2.8966e-04
# Epoch 20/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.5217e-06 - val_loss: 3.1398e-04
# Epoch 21/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.6565e-05 - val_loss: 3.6960e-04
# Epoch 22/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.5375e-05 - val_loss: 2.3204e-04
# Epoch 23/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0679e-05 - val_loss: 2.6564e-04
# Epoch 24/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1
100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.9879e-06 - val_loss: 2.4653e-04
# Epoch 73/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0385e-05 - val_loss: 1.9895e-04
# Epoch 74/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.2856e-06 - val_loss: 1.9756e-04
# Epoch 75/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0127e-05 - val_loss: 2.3649e-04
# Epoch 76/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0704e-05 - val_loss: 2.1305e-04
# Epoch 77/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.6373e-06 - val_loss: 2.1205e-04
# Epoch 78/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.2490e-05 - val_loss: 2.0281e-04
# Epoch 79/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.1193e-06 - val_loss: 2.5887e-04
# Epoch 80/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.5593e-06 - val_loss: 3.7197e-04
# Epoch 81/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0222e-05 - val_loss: 2.1264e-04
# Epoch 82/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.8983e-06 - val_loss: 2.0711e-04
# Epoch 83/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.1240e-05 - val_loss: 2.0130e-04
# Epoch 84/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.5252e-06 - val_loss: 2.0448e-04
# Epoch 85/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.2622e-06 - val_loss: 2.0111e-04
# Epoch 86/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.2295e-06 - val_loss: 2.0151e-04
# Epoch 87/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0107e-05 - val_loss: 2.0059e-04
# Epoch 88/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.9550e-06 - val_loss: 2.2129e-04
# Epoch 89/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.4458e-06 - val_loss: 2.1036e-04
# Epoch 90/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.1051e-06 - val_loss: 1.9932e-04
# Epoch 91/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.8447e-06 - val_loss: 2.9401e-04
# Epoch 92/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 9.6353e-06 - val_loss: 2.0275e-04
# Epoch 93/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0880e-05 - val_loss: 3.0131e-04
# Epoch 94/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.3023e-05 - val_loss: 3.2246e-04
# Epoch 95/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.0557e-05 - val_loss: 2.5245e-04
# Epoch 96/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.2799e-06 - val_loss: 2.3316e-04
# Epoch 97/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.5895e-06 - val_loss: 3.6670e-04
# Epoch 98/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0933e-05 - val_loss: 2.3293e-04
# Epoch 99/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.7185e-06 - val_loss: 3.8762e-04
# Epoch 100/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.1560e-06 - val_loss: 3.5133e-04

# %% [markdown]
# ## Make Predictions + RMSE

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(np.concatenate((np.zeros((predictions.shape[0], 3)), predictions, np.zeros((predictions.shape[0], 1))), axis=1))[:, 3]
y_test = scaler.inverse_transform(np.concatenate((np.zeros((y_test.shape[0], 3)), y_test.reshape(-1, 1), np.zeros((y_test.shape[0], 1))), axis=1))[:, 3]

rmse = np.sqrt(np.mean((predictions - y_test)**2))
print(f"RMSE (with OHLC + Volume): {rmse}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RMSE (with OHLC + Volume): 6.610173202533151

# %% [markdown]
# # Plot Predictions + Hardware Usage

# %%
import matplotlib.pyplot as plt

# Plot the results
plt.figure(figsize=(14,5))
plt.plot(y_test, label='Actual')
plt.plot(predictions, label='Predicted')
plt.title("Actual vs Predicted Stock Prices")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %%
epochs = range(len(cpu_usage_log))

plt.figure(figsize=(14,6))

plt.subplot(2,1,1)
plt.plot(epochs, cpu_usage_log, label='CPU Usage (%)')
plt.xlabel("Epoch")
plt.ylabel("CPU %")
plt.legend()

plt.subplot(2,1,2)
plt.plot(epochs, memory_usage_log, label='Memory Usage (MB)')
plt.xlabel("Epoch")
plt.ylabel("Memory (MB)")
plt.legend()

plt.tight_layout()
plt.show()
