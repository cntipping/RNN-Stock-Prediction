# %% [markdown]
# # Stock Predicition GRU (Base + Vol)

# %% [markdown]
# ## Import Libraries + Download Data + Fetch Stock Data

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import psutil
import os
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.activations import elu
from tensorflow.keras.layers import LeakyReLU

# %%
cpu_usage_log = []
memory_usage_log = []

# %%
ticker = "AAPL"
data = yf.download(ticker, start="2010-01-01", end="2023-11-13")
df = data[['Close', 'Volume']].reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## CPU + RAM Monitoring

# %%
def log_hardware_usage():
    process = psutil.Process(os.getpid())
    cpu_percent = psutil.cpu_percent(interval=1)
    memory_info = process.memory_info()
    
    cpu_usage_log.append(cpu_percent)
    memory_usage_log.append(memory_info.rss / 1024 ** 2)  # in MB

from tensorflow.keras.callbacks import Callback

class HardwareLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        log_hardware_usage()

# %% [markdown]
# ## Prep Data

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['Close', 'Volume']])

# %% [markdown]
# ## Choose activation

# %%
hidden_activation = 'relu'  # Options: 'relu', elu, LeakyReLU(alpha=0.01), 'tanh'
recurrent_activation = 'sigmoid'

# %% [markdown]
# ## Create Sequences

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

seq_length = 60
X, y = create_sequences(scaled_data, seq_length)

# %% [markdown]
# ## Split Data

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# ## Build GRU Model

# %%
model = Sequential([
    GRU(50, return_sequences=True, input_shape=(seq_length, X_train.shape[2]),
        activation=hidden_activation, recurrent_activation=recurrent_activation),
    GRU(50, return_sequences=False,
        activation=hidden_activation, recurrent_activation=recurrent_activation),
    Dense(25, activation='relu'),
    Dense(1)
])
# Out:
# /opt/anaconda3/envs/stock_pred/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Train Model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)
hardware_logger = HardwareLogger()
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_split=0.1, verbose=1, callbacks=[tensorboard_callback, hardware_logger])
# Out:
# Epoch 1/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0050 - val_loss: 0.0074
# Epoch 2/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0669e-04 - val_loss: 0.0049
# Epoch 3/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 5.2635e-05 - val_loss: 0.0039
# Epoch 4/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.1934e-05 - val_loss: 0.0037
# Epoch 5/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.7847e-05 - val_loss: 0.0035
# Epoch 6/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.3387e-05 - val_loss: 0.0037
# Epoch 7/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.8329e-05 - val_loss: 0.0041
# Epoch 8/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.6044e-05 - val_loss: 0.0045
# Epoch 9/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.6400e-05 - val_loss: 0.0045
# Epoch 10/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.6123e-05 - val_loss: 0.0043
# Epoch 11/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2770e-05 - val_loss: 0.0040
# Epoch 12/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.5885e-05 - val_loss: 0.0033
# Epoch 13/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.7262e-05 - val_loss: 0.0039
# Epoch 14/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.4880e-05 - val_loss: 0.0044
# Epoch 15/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.3801e-05 - val_loss: 0.0036
# Epoch 16/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.7232e-05 - val_loss: 0.0040
# Epoch 17/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.1797e-05 - val_loss: 0.0036
# Epoch 18/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.5802e-05 - val_loss: 0.0040
# Epoch 19/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.3517e-05 - val_loss: 0.0042
# Epoch 20/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.5153e-05 - val_loss: 0.0038
# Epoch 21/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.3653e-05 - val_loss: 0.0044
# Epoch 22/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.9849e-05 - val_loss: 0.0040
# Epoch 23/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0742e-05 - val_loss: 0.0035
# Epoch 24/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2191e-05 - val_loss: 0.0041
# Epoch 25/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.4820e-05 - val_loss: 0.0030
# Epoch 26/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2075e-05 - val_loss: 0.0033
# Epoch 27/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.5964e-05 - val_loss: 0.0035
# Epoch 28/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.7898e-05 - val_loss: 0.0032
# Epoch 29/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0787e-05 - val_loss: 0.0043
# Epoch 30/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.0782e-05 - val_loss: 0.0030
# Epoch 31/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.6693e-06 - val_loss: 0.0037
# Epoch 32/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.1570e-05 - val_loss: 0.0032
# Epoch 33/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.3068e-05 - val_loss: 0.0027
# Epoch 34/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.5191e-05 - val_loss: 0.0038
# Epoch 35/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.1422e-06 - val_loss: 0.0034
# Epoch 36/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0218e-05 - val_loss: 0.0030
# Epoch 37/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.4261e-05 - val_loss: 0.0033
# Epoch 38/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.2576e-05 - val_loss: 0.0035
# Epoch 39/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.1432e-05 - val_loss: 0.0029
# Epoch 40/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.1314e-05 - val_loss: 0.0031
# Epoch 41/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.5416e-06 - val_loss: 0.0035
# Epoch 42/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.1905e-05 - val_loss: 0.0035
# Epoch 43/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.5869e-06 - val_loss: 0.0029
# Epoch 44/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.4506e-06 - val_loss: 0.0029
# Epoch 45/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.8677e-06 - val_loss: 0.0029
# Epoch 46/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.2072e-05 - val_loss: 0.0029
# Epoch 47/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.7343e-06 - val_loss: 0.0030
# Epoch 48/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0512e-05 - val_loss: 0.0028
# Epoch 49/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.0690e-05 - val_loss: 0.0024
# Epoch 50/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.1001e-06 - val_loss: 0.0022
# Epoch 51/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.1407e-06 - val_loss: 0.0026
# Epoch 52/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0999e-05 - val_loss: 0.0026
# Epoch 53/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0364e-05 - val_loss: 0.0022
# Epoch 54/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.1293e-05 - val_loss: 0.0025
# Epoch 55/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.4396e-06 - val_loss: 0.0025
# Epoch 56/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.6887e-06 - val_loss: 0.0019
# Epoch 57/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0538e-05 - val_loss: 0.0019
# Epoch 58/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0353e-05 - val_loss: 0.0026
# Epoch 59/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.6083e-06 - val_loss: 0.0023
# Epoch 60/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.1390e-06 - val_loss: 0.0022
# Epoch 61/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2509e-05 - val_loss: 0.0023
# Epoch 62/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.1867e-05 - val_loss: 0.0021
# Epoch 63/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.5216e-06 - val_loss: 0.0016
# Epoch 64/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.4716e-06 - val_loss: 0.0016
# Epoch 65/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0018e-05 - val_loss: 0.0024
# Epoch 66/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.5304e-05 - val_loss: 0.0021
# Epoch 67/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.5661e-06 - val_loss: 0.0025
# Epoch 68/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.0034e-06 - val_loss: 0.0022
# Epoch 69/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.5459e-06 - val_loss: 0.0018
# Epoch 70/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.3731e-06 - val_loss: 0.0018
# Epoch 71/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.5355e-06 - val_loss: 0.0017
# Epoch 72/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.9661e-06 - val_loss: 0.0020
# Epoch 73/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.4262e-06 - val_loss: 0.0023
# Epoch 74/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.8167e-06 - val_loss: 0.0020
# Epoch 75/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.8679e-06 - val_loss: 0.0014
# Epoch 76/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.3568e-05 - val_loss: 0.0012
# Epoch 77/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.8625e-06 - val_loss: 0.0016
# Epoch 78/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.3086e-06 - val_loss: 0.0016
# Epoch 79/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.8952e-06 - val_loss: 0.0022
# Epoch 80/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.6530e-06 - val_loss: 0.0019
# Epoch 81/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.0632e-06 - val_loss: 0.0014
# Epoch 82/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.5777e-06 - val_loss: 0.0012
# Epoch 83/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2047e-05 - val_loss: 0.0014
# Epoch 84/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.4861e-06 - val_loss: 0.0014
# Epoch 85/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.0759e-06 - val_loss: 0.0013
# Epoch 86/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.9463e-06 - val_loss: 0.0012
# Epoch 87/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.1632e-06 - val_loss: 0.0012
# Epoch 88/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.7409e-06 - val_loss: 0.0013
# Epoch 89/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.2328e-06 - val_loss: 0.0020
# Epoch 90/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.3006e-06 - val_loss: 0.0013
# Epoch 91/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.1360e-05 - val_loss: 0.0012
# Epoch 92/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.9882e-06 - val_loss: 0.0012
# Epoch 93/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.0517e-06 - val_loss: 9.9997e-04
# Epoch 94/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.4883e-06 - val_loss: 7.6423e-04
# Epoch 95/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.7009e-06 - val_loss: 8.5331e-04
# Epoch 96/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.9286e-06 - val_loss: 4.5893e-04
# Epoch 97/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2371e-05 - val_loss: 9.3932e-04
# Epoch 98/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.3937e-06 - val_loss: 7.9771e-04
# Epoch 99/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.6315e-06 - val_loss: 0.0012
# Epoch 100/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.0241e-06 - val_loss: 8.8576e-04

# %% [markdown]
# ## Make Predictions + RMSE

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(np.concatenate((predictions, np.zeros_like(predictions)), axis=1))[:, 0]
y_test = scaler.inverse_transform(np.concatenate((y_test.reshape(-1, 1), np.zeros_like(y_test.reshape(-1, 1))), axis=1))[:, 0]

rmse = np.sqrt(np.mean((predictions - y_test)**2))
print(f"RMSE (with Volume): {rmse}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RMSE (with Volume): 14.616183766659608

# %% [markdown]
# # Plot Predictions + Hardware Usage

# %%
import matplotlib.pyplot as plt

# Plot the results
plt.figure(figsize=(14,5))
plt.plot(y_test, label='Actual')
plt.plot(predictions, label='Predicted')
plt.title("Actual vs Predicted Stock Prices")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %%
epochs = range(len(cpu_usage_log))

plt.figure(figsize=(14,6))

plt.subplot(2,1,1)
plt.plot(epochs, cpu_usage_log, label='CPU Usage (%)')
plt.xlabel("Epoch")
plt.ylabel("CPU %")
plt.legend()

plt.subplot(2,1,2)
plt.plot(epochs, memory_usage_log, label='Memory Usage (MB)')
plt.xlabel("Epoch")
plt.ylabel("Memory (MB)")
plt.legend()

plt.tight_layout()
plt.show()
