# %% [markdown]
# # Stock Predicition GRU (Base + Vol)

# %% [markdown]
# ## Import Libraries + Download Data + Fetch Stock Data

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import psutil
import os
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GRU
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.activations import elu
from tensorflow.keras.layers import LeakyReLU
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
cpu_usage_log = []
memory_usage_log = []

# %%
ticker = "AAPL"
data = yf.download(ticker, start="2010-01-01", end="2023-11-13")
df = data[['Close', 'Volume']].reset_index()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## CPU + RAM Monitoring

# %%
def log_hardware_usage():
    process = psutil.Process(os.getpid())
    cpu_percent = psutil.cpu_percent(interval=1)
    memory_info = process.memory_info()
    
    cpu_usage_log.append(cpu_percent)
    memory_usage_log.append(memory_info.rss / 1024 ** 2)  # in MB

from tensorflow.keras.callbacks import Callback

class HardwareLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        log_hardware_usage()

# %% [markdown]
# ## Prep Data

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[['Close', 'Volume']])

# %% [markdown]
# ## Choose activation

# %%
hidden_activation = LeakyReLU(alpha=0.01)
  # Options: 'relu', elu, LeakyReLU(alpha=0.01), 'tanh'
recurrent_activation = 'sigmoid'
# Out:
# /opt/anaconda3/envs/stock_pred/lib/python3.10/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %% [markdown]
# ## Create Sequences

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

seq_length = 60
X, y = create_sequences(scaled_data, seq_length)

# %% [markdown]
# ## Split Data

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# ## Build GRU Model

# %%
model = Sequential([
    GRU(50, return_sequences=True, input_shape=(seq_length, X_train.shape[2]),
        activation=hidden_activation, recurrent_activation=recurrent_activation),
    GRU(50, return_sequences=False,
        activation=hidden_activation, recurrent_activation=recurrent_activation),
    Dense(25, activation='relu'),
    Dense(1)
])
# Out:
# /opt/anaconda3/envs/stock_pred/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Train Model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
tensorboard_callback = TensorBoard(log_dir="./logs", histogram_freq=1)
hardware_logger = HardwareLogger()
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_split=0.1, verbose=1, callbacks=[tensorboard_callback, hardware_logger])
# Out:
# Epoch 1/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0065 - val_loss: 0.0115
# Epoch 2/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.6437e-04 - val_loss: 0.0037
# Epoch 3/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 3.0233e-05 - val_loss: 0.0036
# Epoch 4/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.9684e-05 - val_loss: 0.0034
# Epoch 5/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.7686e-05 - val_loss: 0.0029
# Epoch 6/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.6357e-05 - val_loss: 0.0029
# Epoch 7/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.2258e-05 - val_loss: 0.0028
# Epoch 8/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.0198e-05 - val_loss: 0.0031
# Epoch 9/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.7857e-05 - val_loss: 0.0030
# Epoch 10/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.7683e-05 - val_loss: 0.0024
# Epoch 11/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.1060e-05 - val_loss: 0.0032
# Epoch 12/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.7674e-05 - val_loss: 0.0030
# Epoch 13/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.6882e-05 - val_loss: 0.0030
# Epoch 14/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.3752e-05 - val_loss: 0.0030
# Epoch 15/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.3263e-05 - val_loss: 0.0026
# Epoch 16/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.6495e-05 - val_loss: 0.0027
# Epoch 17/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1
100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.2696e-06 - val_loss: 0.0017
# Epoch 71/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.6000e-06 - val_loss: 0.0020
# Epoch 72/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.6421e-06 - val_loss: 0.0027
# Epoch 73/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 2.1038e-05 - val_loss: 0.0015
# Epoch 74/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.1534e-05 - val_loss: 0.0017
# Epoch 75/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.8415e-06 - val_loss: 0.0018
# Epoch 76/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.2032e-06 - val_loss: 0.0020
# Epoch 77/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0724e-05 - val_loss: 0.0018
# Epoch 78/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.0314e-06 - val_loss: 0.0016
# Epoch 79/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.5188e-06 - val_loss: 0.0019
# Epoch 80/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.7096e-06 - val_loss: 0.0020
# Epoch 81/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.9139e-06 - val_loss: 0.0022
# Epoch 82/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.9584e-06 - val_loss: 0.0012
# Epoch 83/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.7509e-06 - val_loss: 0.0021
# Epoch 84/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.0078e-05 - val_loss: 0.0018
# Epoch 85/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0366e-05 - val_loss: 0.0015
# Epoch 86/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.9491e-06 - val_loss: 0.0020
# Epoch 87/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.7359e-06 - val_loss: 0.0014
# Epoch 88/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.0625e-06 - val_loss: 0.0014
# Epoch 89/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.8989e-06 - val_loss: 0.0014
# Epoch 90/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.1520e-06 - val_loss: 0.0022
# Epoch 91/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.5291e-06 - val_loss: 0.0015
# Epoch 92/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.3806e-06 - val_loss: 0.0016
# Epoch 93/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.9530e-06 - val_loss: 0.0014
# Epoch 94/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 9.6066e-06 - val_loss: 0.0018
# Epoch 95/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 7.9889e-06 - val_loss: 0.0019
# Epoch 96/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 7.2519e-06 - val_loss: 0.0020
# Epoch 97/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.0078e-05 - val_loss: 0.0010
# Epoch 98/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.0047e-05 - val_loss: 0.0011
# Epoch 99/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 7.9821e-06 - val_loss: 0.0016
# Epoch 100/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.3625e-06 - val_loss: 0.0029

# %% [markdown]
# ## Make Predictions + RMSE

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(np.concatenate((predictions, np.zeros_like(predictions)), axis=1))[:, 0]
y_test = scaler.inverse_transform(np.concatenate((y_test.reshape(-1, 1), np.zeros_like(y_test.reshape(-1, 1))), axis=1))[:, 0]

rmse = np.sqrt(np.mean((predictions - y_test)**2))
print(f"RMSE (with Volume): {rmse}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# RMSE (with Volume): 23.01759995300355

# %% [markdown]
# # Plot Predictions + Hardware Usage

# %%
import matplotlib.pyplot as plt

# Plot the results
plt.figure(figsize=(14,5))
plt.plot(y_test, label='Actual')
plt.plot(predictions, label='Predicted')
plt.title("Actual vs Predicted Stock Prices")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %%
epochs = range(len(cpu_usage_log))

plt.figure(figsize=(14,6))

plt.subplot(2,1,1)
plt.plot(epochs, cpu_usage_log, label='CPU Usage (%)')
plt.xlabel("Epoch")
plt.ylabel("CPU %")
plt.legend()

plt.subplot(2,1,2)
plt.plot(epochs, memory_usage_log, label='Memory Usage (MB)')
plt.xlabel("Epoch")
plt.ylabel("Memory (MB)")
plt.legend()

plt.tight_layout()
plt.show()
